# %%
import talos as ta
import pandas as pd

# %%
d = pd.read_csv('higgs_nn_2.csv')

# %%
r = ta.Reporting('higgs_nn_2.csv')

# %%
r.table()
# Out:
#      val_acc  optimizer                               dropout  batch_size  \
# 25  0.635001          3  <function sigmoid at 0x7fbc521466e0>         0.4
# 24  0.634222          6  <function sigmoid at 0x7fbc521466e0>         0.3
# 26  0.634028          2  <function sigmoid at 0x7fbc521466e0>         0.4
# 48  0.634028          3  <function sigmoid at 0x7fbc521466e0>         0.4
# 42  0.634028          2  <function sigmoid at 0x7fbc521466e0>         0.3
# 12  0.633444          3  <function sigmoid at 0x7fbc521466e0>         0.0
# 32  0.632470          3  <function sigmoid at 0x7fbc521466e0>         0.3
# 47  0.631886          3  <function sigmoid at 0x7fbc521466e0>         0.2
# 30  0.631497          5  <function sigmoid at 0x7fbc521466e0>         0.2
# 17  0.631108          2  <function sigmoid at 0x7fbc521466e0>         0.1
# 45  0.630913          3  <function sigmoid at 0x7fbc521466e0>         0.4
# 28  0.630524          6  <function sigmoid at 0x7fbc521466e0>         0.1
# ...

# %%
r.plot_hist()

# %%
r.high()
# Out:
# 0.6350009733307378
