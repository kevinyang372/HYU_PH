# %%
import talos as ta
import pandas as pd

# %%
d = pd.read_csv('higgs_nn_2.csv')

# %%
r = ta.Reporting('higgs_nn_2.csv')

# %%
r.table()
# Out:
#        val_acc  optimizer                               dropout  batch_size  \
# 62    0.643177          6  <function sigmoid at 0x7f3b217e5578>         0.3
# 1287  0.642593          4  <function sigmoid at 0x7f3b217e5578>         0.3
# 653   0.642204          6  <function sigmoid at 0x7f3b217e5578>         0.3
# 1185  0.640257          4  <function sigmoid at 0x7f3b217e5578>         0.3
# 999   0.640062          5  <function sigmoid at 0x7f3b217e5578>         0.1
# 176   0.639478          4  <function sigmoid at 0x7f3b217e5578>         0.0
# 1064  0.639089          4  <function sigmoid at 0x7f3b217e5578>         0.3
# 710   0.639089          5  <function sigmoid at 0x7f3b217e5578>         0.4
# 347   0.639089          4  <function sigmoid at 0x7f3b217e5578>         0.3
# 409   0.638894          4  <function sigmoid at 0x7f3b217e5578>         0.2
# 849   0.638894          4  <function sigmoid at 0x7f3b217e5578>         0.2
# ...

# %%
r.plot_hist()

# %%
r.high()
# Out:
# 0.6431769515281293
