# %%
import talos as ta
import pandas as pd

# %%
d = pd.read_csv('higgs_nn_1.csv')

# %%
r = ta.Reporting('higgs_nn_1.csv')

# %%
r.table()
# Out:
#       val_acc  optimizer                               dropout  batch_size  \
# 79   0.635780          5  <function sigmoid at 0x7f29a9c066e0>         0.4
# 541  0.633833          3  <function sigmoid at 0x7f29a9c066e0>         0.4
# 460  0.633444          3  <function sigmoid at 0x7f29a9c066e0>         0.2
# 351  0.633054          2  <function sigmoid at 0x7f29a9c066e0>         0.3
# 136  0.632470          6  <function sigmoid at 0x7f29a9c066e0>         0.3
# 190  0.632276          2  <function sigmoid at 0x7f29a9c066e0>         0.3
# 208  0.632081          2  <function sigmoid at 0x7f29a9c066e0>         0.0
# 253  0.631497          4  <function sigmoid at 0x7f29a9c066e0>         0.1
# 101  0.631302          6  <function sigmoid at 0x7f29a9c066e0>         0.4
# 436  0.631302          4  <function sigmoid at 0x7f29a9c066e0>         0.2
# 142  0.631108          4  <function sigmoid at 0x7f29a9c066e0>         0.4
# ...

# %%
r.plot_hist()

# %%
r.high()
# Out:
# 0.6357796379209656
